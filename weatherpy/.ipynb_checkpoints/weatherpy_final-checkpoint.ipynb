# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as mpl
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
#from api_keys import weather_api_key
weather_api_key = "cec57c519290146f9db7fd7cb83295e5"
# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)
print(weather_api_key)
# Out:
# cec57c519290146f9db7fd7cb83295e5

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 636

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?q="

temp = []
feels_like = []
temp_min = []
temp_max = []
pressure = []
humidity = []
visibility = []
lat = []
lng = []
city_name = []
cloudiness = []
date = []
country = []
wind_speed = []

count = 0
for city in cities:
    city = city
    query_url = url + city + "&appid=" + weather_api_key
    response = requests.get(query_url).json()
    try:
        temp.append(response["main"]["temp"])
        feels_like.append(response["main"]["feels_like"])
        temp_min.append(response["main"]["temp_min"])
        temp_max.append(response["main"]["temp_max"])
        pressure.append(response["main"]["pressure"])
        humidity.append(response["main"]["humidity"])
        visibility.append(response["visibility"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        city_name.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        date.append(response["dt"])
        country.append(response["sys"]["country"])
        wind_speed.append(response["wind"]["speed"])
        print(f"City loading: {city} : Number {count}")
        count += 1
    except (KeyError):
        print("Error: city not found")
# Out:
# Error: city not found
# Error: city not found
# City loading: mataura : Number 0
# Error: city not found
# City loading: thompson : Number 1
# City loading: batagay-alyta : Number 2
# City loading: carballo : Number 3
# City loading: bredasdorp : Number 4
# City loading: yellowknife : Number 5
# Error: city not found
# Error: city not found
# City loading: pevek : Number 6
# City loading: chokurdakh : Number 7
# City loading: puerto ayora : Number 8
# City loading: faanui : Number 9
# City loading: vaini : Number 10
# City loading: lata : Number 11
# City loading: tasiilaq : Number 12
# City loading: severo-kurilsk : Number 13
# City loading: sobolevo : Number 14
# City loading: kurilsk : Number 15
# Error: city not found
# City loading: devils lake : Number 16
# City loading: ribeira grande : Number 17
# City loading: buenos aires : Number 18
# City loading: kahului : Number 19
# Error: city not found
# City loading: port elizabeth : Number 20
# City loading: isangel : Number 21
# City loading: huarmey : Number 22
# City loading: vila velha : Number 23
# City loading: castro alves : Number 24
# City loading: roald : Number 25
# City loading: souillac : Number 26
# City loading: hualmay : Number 27
# City loading: vestmannaeyjar : Number 28
# City loading: cooma : Number 29
# City loading: soron : Number 30
# City loading: naryan-mar : Number 31
# Error: city not found
# Error: city not found
# City loading: maniitsoq : Number 32
# City loading: codrington : Number 33
# City loading: weinan : Number 34
# City loading: tiznit : Number 35
# City loading: hermanus : Number 36
# City loading: careiro da varzea : Number 37
# City loading: ranong : Number 38
# City loading: saskylakh : Number 39
# City loading: ushuaia : Number 40
# City loading: kushima : Number 41
# City loading: busselton : Number 42
# City loading: kodiak : Number 43
# City loading: samarai : Number 44
# City loading: bomet : Number 45
# City loading: bluff : Number 46
# City loading: santa rosa : Number 47
# City loading: baicheng : Number 48
# City loading: jamestown : Number 49
# City loading: atuona : Number 50
# City loading: melchor de mencos : Number 51
# City loading: atbasar : Number 52
# City loading: aykhal : Number 53
# City loading: kudahuvadhoo : Number 54
# City loading: awbari : Number 55
# City loading: kapaa : Number 56
# City loading: rosita : Number 57
# City loading: norman wells : Number 58
# City loading: bambous virieux : Number 59
# City loading: aloleng : Number 60
# City loading: cidreira : Number 61
# City loading: husavik : Number 62
# City loading: sept-iles : Number 63
# City loading: guerrero negro : Number 64
# City loading: tuktoyaktuk : Number 65
# City loading: pavino : Number 66
# City loading: hobart : Number 67
# City loading: henties bay : Number 68
# City loading: port alfred : Number 69
# City loading: ancud : Number 70
# City loading: lebu : Number 71
# City loading: arraial do cabo : Number 72
# City loading: hilo : Number 73
# City loading: butaritari : Number 74
# City loading: rabo de peixe : Number 75
# City loading: new norfolk : Number 76
# City loading: nador : Number 77
# City loading: saint-pierre : Number 78
# City loading: teya : Number 79
# City loading: cape town : Number 80
# City loading: diffa : Number 81
# City loading: khatanga : Number 82
# City loading: oussouye : Number 83
# City loading: narsaq : Number 84
# City loading: hamilton : Number 85
# City loading: provideniya : Number 86
# Error: city not found
# City loading: natal : Number 87
# City loading: grindavik : Number 88
# City loading: nanortalik : Number 89
# City loading: rancho palos verdes : Number 90
# City loading: chuy : Number 91
# City loading: constitucion : Number 92
# City loading: kokoda : Number 93
# City loading: punta arenas : Number 94
# City loading: kikwit : Number 95
# City loading: chalchihuites : Number 96
# City loading: mkushi : Number 97
# City loading: hokitika : Number 98
# City loading: gao : Number 99
# City loading: susangerd : Number 100
# City loading: del rio : Number 101
# City loading: qaanaaq : Number 102
# City loading: swan river : Number 103
# City loading: shiraoi : Number 104
# City loading: georgetown : Number 105
# City loading: christchurch : Number 106
# City loading: dikson : Number 107
# City loading: mount gambier : Number 108
# City loading: stornoway : Number 109
# City loading: richards bay : Number 110
# City loading: qaqortoq : Number 111
# City loading: port hedland : Number 112
# City loading: albany : Number 113
# City loading: veraval : Number 114
# City loading: portland : Number 115
# City loading: rikitea : Number 116
# City loading: glace bay : Number 117
# City loading: kasamwa : Number 118
# City loading: hofn : Number 119
# City loading: caravelas : Number 120
# City loading: cabo san lucas : Number 121
# City loading: korla : Number 122
# City loading: port hardy : Number 123
# City loading: buguruslan : Number 124
# City loading: dingle : Number 125
# City loading: saint george : Number 126
# Error: city not found
# City loading: port lincoln : Number 127
# City loading: boca do acre : Number 128
# City loading: massakory : Number 129
# Error: city not found
# City loading: ballina : Number 130
# City loading: katsuura : Number 131
# City loading: avarua : Number 132
# City loading: kruisfontein : Number 133
# City loading: ixtapa : Number 134
# City loading: malakal : Number 135
# City loading: geraldton : Number 136
# City loading: risor : Number 137
# City loading: gribanovskiy : Number 138
# Error: city not found
# City loading: esperance : Number 139
# City loading: paamiut : Number 140
# City loading: nampa : Number 141
# City loading: tiksi : Number 142
# City loading: kisangani : Number 143
# City loading: kristianstad : Number 144
# City loading: monrovia : Number 145
# Error: city not found
# City loading: ardmore : Number 146
# City loading: san patricio : Number 147
# City loading: san : Number 148
# City loading: mahon : Number 149
# City loading: ponta do sol : Number 150
# City loading: ordzhonikidze : Number 151
# City loading: sirsa : Number 152
# City loading: sakakah : Number 153
# City loading: erenhot : Number 154
# City loading: padampur : Number 155
# City loading: nabire : Number 156
# City loading: mar del plata : Number 157
# City loading: ko samui : Number 158
# City loading: nuuk : Number 159
# City loading: santa cruz : Number 160
# City loading: sioux lookout : Number 161
# City loading: aksha : Number 162
# City loading: kahramanmaras : Number 163
# City loading: iracoubo : Number 164
# City loading: neuquen : Number 165
# City loading: kiunga : Number 166
# City loading: martin : Number 167
# City loading: iqaluit : Number 168
# City loading: salinopolis : Number 169
# City loading: bethel : Number 170
# City loading: sinegorye : Number 171
# City loading: leningradskiy : Number 172
# City loading: hasaki : Number 173
# City loading: quito : Number 174
# City loading: tura : Number 175
# City loading: ucluelet : Number 176
# City loading: airai : Number 177
# City loading: lufkin : Number 178
# City loading: segezha : Number 179
# City loading: cururupu : Number 180
# City loading: aklavik : Number 181
# City loading: te anau : Number 182
# City loading: udachnyy : Number 183
# City loading: cedar city : Number 184
# City loading: manzhouli : Number 185
# City loading: laguna : Number 186
# City loading: ravar : Number 187
# City loading: karakol : Number 188
# City loading: at-bashi : Number 189
# Error: city not found
# City loading: venado tuerto : Number 190
# City loading: saurimo : Number 191
# City loading: clyde river : Number 192
# City loading: la ronge : Number 193
# City loading: baykit : Number 194
# City loading: washington : Number 195
# City loading: kangaatsiaq : Number 196
# City loading: merauke : Number 197
# Error: city not found
# City loading: manono : Number 198
# City loading: lavrentiya : Number 199
# City loading: binga : Number 200
# City loading: bucinisu : Number 201
# City loading: east london : Number 202
# City loading: pacific grove : Number 203
# City loading: isla mujeres : Number 204
# City loading: dubrovnik : Number 205
# City loading: vao : Number 206
# City loading: barrow : Number 207
# City loading: emba : Number 208
# Error: city not found
# City loading: bereznik : Number 209
# City loading: port hawkesbury : Number 210
# City loading: placido de castro : Number 211
# City loading: vila franca do campo : Number 212
# City loading: san cristobal : Number 213
# City loading: hovd : Number 214
# City loading: nikolskoye : Number 215
# Error: city not found
# City loading: lamu : Number 216
# City loading: deputatskiy : Number 217
# City loading: labuhan : Number 218
# Error: city not found
# City loading: bengkulu : Number 219
# City loading: ust-kuyga : Number 220
# Error: city not found
# City loading: saint-philippe : Number 221
# City loading: upernavik : Number 222
# City loading: ozerna : Number 223
# City loading: ta khmau : Number 224
# City loading: zeerust : Number 225
# City loading: owensboro : Number 226
# City loading: yashkul : Number 227
# City loading: coquimbo : Number 228
# City loading: beloha : Number 229
# City loading: craigieburn : Number 230
# City loading: dhidhdhoo : Number 231
# City loading: reconquista : Number 232
# City loading: torbay : Number 233
# City loading: samagaltay : Number 234
# Error: city not found
# City loading: tupik : Number 235
# City loading: ostrovnoy : Number 236
# City loading: sorland : Number 237
# City loading: minggang : Number 238
# City loading: samarkand : Number 239
# City loading: lorengau : Number 240
# City loading: kupino : Number 241
# City loading: sola : Number 242
# City loading: umm kaddadah : Number 243
# City loading: neiafu : Number 244
# City loading: naujamiestis : Number 245
# City loading: omsukchan : Number 246
# Error: city not found
# City loading: evensk : Number 247
# City loading: hauterive : Number 248
# City loading: trapani : Number 249
# City loading: ayan : Number 250
# Error: city not found
# City loading: san jose : Number 251
# City loading: ahipara : Number 252
# City loading: sesheke : Number 253
# City loading: colares : Number 254
# City loading: horni jiretin : Number 255
# City loading: sumbawanga : Number 256
# City loading: gandajika : Number 257
# Error: city not found
# City loading: muzaffarabad : Number 258
# City loading: jumla : Number 259
# City loading: samandag : Number 260
# City loading: koumac : Number 261
# City loading: mahebourg : Number 262
# Error: city not found
# City loading: banda aceh : Number 263
# City loading: aketi : Number 264
# City loading: bandarbeyla : Number 265
# City loading: ongandjera : Number 266
# City loading: ammon : Number 267
# City loading: cap-aux-meules : Number 268
# City loading: ust-nera : Number 269
# City loading: novyy urengoy : Number 270
# City loading: carutapera : Number 271
# Error: city not found
# City loading: sur : Number 272
# City loading: hithadhoo : Number 273
# City loading: cullman : Number 274
# City loading: kuching : Number 275
# City loading: sitrah : Number 276
# City loading: cayenne : Number 277
# City loading: luanda : Number 278
# City loading: katima mulilo : Number 279
# City loading: porto de moz : Number 280
# City loading: yangambi : Number 281
# Error: city not found
# City loading: mercedes : Number 282
# City loading: brandon : Number 283
# Error: city not found
# City loading: woodward : Number 284
# Error: city not found
# Error: city not found
# City loading: poum : Number 285
# City loading: verkh-usugli : Number 286
# City loading: danao : Number 287
# City loading: pangnirtung : Number 288
# City loading: tabuk : Number 289
# City loading: jinchang : Number 290
# City loading: yulara : Number 291
# City loading: la rioja : Number 292
# City loading: pandan : Number 293
# City loading: bathsheba : Number 294
# City loading: bagdarin : Number 295
# City loading: dire dawa : Number 296
# City loading: acoua : Number 297
# City loading: fort nelson : Number 298
# City loading: beringovskiy : Number 299
# City loading: westport : Number 300
# City loading: watertown : Number 301
# City loading: hobbs : Number 302
# City loading: camopi : Number 303
# City loading: kamaishi : Number 304
# City loading: kushiro : Number 305
# City loading: romitan : Number 306
# City loading: andenes : Number 307
# Error: city not found
# City loading: puerto ayacucho : Number 308
# City loading: yakeshi : Number 309
# City loading: belaya gora : Number 310
# City loading: palauig : Number 311
# City loading: linqiong : Number 312
# City loading: grand gaube : Number 313
# City loading: bergen : Number 314
# City loading: daru : Number 315
# City loading: comodoro rivadavia : Number 316
# City loading: solnechnyy : Number 317
# City loading: naze : Number 318
# City loading: mishelevka : Number 319
# City loading: luganville : Number 320
# City loading: svetlyy : Number 321
# City loading: awjilah : Number 322
# City loading: gamba : Number 323
# City loading: corpus christi : Number 324
# City loading: yasnyy : Number 325
# City loading: almonte : Number 326
# City loading: lompoc : Number 327
# City loading: san policarpo : Number 328
# Error: city not found
# Error: city not found
# City loading: jaru : Number 329
# City loading: hohhot : Number 330
# City loading: maceio : Number 331
# City loading: ilulissat : Number 332
# Error: city not found
# City loading: berlevag : Number 333
# City loading: alappuzha : Number 334
# City loading: olafsvik : Number 335
# City loading: tessaoua : Number 336
# City loading: palmdale : Number 337
# City loading: plouzane : Number 338
# City loading: huanren : Number 339
# City loading: port-gentil : Number 340
# City loading: corinto : Number 341
# City loading: jiwani : Number 342
# Error: city not found
# City loading: santa isabel do rio negro : Number 343
# City loading: tocopilla : Number 344
# City loading: raudeberg : Number 345
# City loading: mayo : Number 346
# City loading: mitu : Number 347
# City loading: tabou : Number 348
# City loading: shunyi : Number 349
# City loading: harnosand : Number 350
# City loading: saint-georges : Number 351
# City loading: xunchang : Number 352
# City loading: puerto escondido : Number 353
# City loading: kavaratti : Number 354
# City loading: rosa zarate : Number 355
# City loading: krasnoselkup : Number 356
# City loading: harbour breton : Number 357
# City loading: jasper : Number 358
# Error: city not found
# Error: city not found
# City loading: mahibadhoo : Number 359
# City loading: biograd na moru : Number 360
# City loading: sitka : Number 361
# City loading: monki : Number 362
# City loading: ca mau : Number 363
# Error: city not found
# City loading: sawakin : Number 364
# City loading: khani : Number 365
# Error: city not found
# Error: city not found
# City loading: carnarvon : Number 366
# City loading: makakilo city : Number 367
# City loading: pajapan : Number 368
# Error: city not found
# City loading: rawson : Number 369
# City loading: san quintin : Number 370
# City loading: touros : Number 371
# City loading: rio gallegos : Number 372
# City loading: mabaruma : Number 373
# City loading: waipawa : Number 374
# City loading: tromso : Number 375
# City loading: bintulu : Number 376
# City loading: honolulu : Number 377
# City loading: halifax : Number 378
# City loading: palana : Number 379
# City loading: manokwari : Number 380
# City loading: paragominas : Number 381
# City loading: victoria : Number 382
# City loading: arawa : Number 383
# City loading: uruzgan : Number 384
# City loading: pontes e lacerda : Number 385
# Error: city not found
# City loading: kozluk : Number 386
# City loading: kawalu : Number 387
# City loading: snezhnogorsk : Number 388
# City loading: cap malheureux : Number 389
# City loading: lagoa : Number 390
# City loading: belyy yar : Number 391
# City loading: faya : Number 392
# City loading: kedrovyy : Number 393
# City loading: nelson bay : Number 394
# City loading: frontera : Number 395
# City loading: gweta : Number 396
# City loading: villeneuve-sur-lot : Number 397
# City loading: chesma : Number 398
# City loading: gainesville : Number 399
# Error: city not found
# City loading: tafresh : Number 400
# City loading: klyuchi : Number 401
# City loading: ler : Number 402
# City loading: vung tau : Number 403
# City loading: zaragoza : Number 404
# City loading: slave lake : Number 405
# Error: city not found
# City loading: lasa : Number 406
# City loading: jacareacanga : Number 407
# City loading: coihaique : Number 408
# City loading: port shepstone : Number 409
# Error: city not found
# City loading: hosur : Number 410
# City loading: buala : Number 411
# City loading: pisco : Number 412
# City loading: caborca : Number 413
# City loading: kupang : Number 414
# City loading: matay : Number 415
# City loading: southbridge : Number 416
# City loading: mandan : Number 417
# City loading: soyo : Number 418
# City loading: verkhnyaya inta : Number 419
# City loading: axim : Number 420
# City loading: horadiz : Number 421
# City loading: little current : Number 422
# City loading: meulaboh : Number 423
# City loading: north bend : Number 424
# City loading: mier : Number 425
# Error: city not found
# City loading: saldanha : Number 426
# City loading: ibra : Number 427
# City loading: fairview : Number 428
# City loading: lewiston : Number 429
# City loading: itaqui : Number 430
# City loading: can : Number 431
# City loading: kousseri : Number 432
# City loading: cockburn town : Number 433
# City loading: itarema : Number 434
# City loading: marzuq : Number 435
# City loading: paita : Number 436
# City loading: hervey bay : Number 437
# City loading: zyryanka : Number 438
# City loading: shirvan : Number 439
# Error: city not found
# City loading: port augusta : Number 440
# City loading: ouagadougou : Number 441
# City loading: aba : Number 442
# Error: city not found
# City loading: karratha : Number 443
# City loading: ollioules : Number 444
# City loading: guapi : Number 445
# City loading: mehamn : Number 446
# City loading: longyearbyen : Number 447
# City loading: madaoua : Number 448
# City loading: tautira : Number 449
# City loading: nolinsk : Number 450
# City loading: khandyga : Number 451
# City loading: ilskiy : Number 452
# Error: city not found
# City loading: vanavara : Number 453
# City loading: fairbanks : Number 454
# City loading: margate : Number 455
# City loading: bonthe : Number 456
# City loading: sao gabriel da cachoeira : Number 457
# City loading: goderich : Number 458
# City loading: pokaran : Number 459
# City loading: craig : Number 460
# City loading: umm lajj : Number 461
# City loading: kavieng : Number 462
# City loading: flin flon : Number 463
# City loading: muros : Number 464
# City loading: vardo : Number 465
# City loading: rio cuarto : Number 466
# City loading: thinadhoo : Number 467
# City loading: leninsk-kuznetskiy : Number 468
# City loading: mosalsk : Number 469
# City loading: fevik : Number 470
# City loading: navolato : Number 471
# Error: city not found
# City loading: los llanos de aridane : Number 472
# City loading: atambua : Number 473
# City loading: prestea : Number 474
# City loading: talnakh : Number 475
# City loading: thohoyandou : Number 476
# City loading: usinsk : Number 477
# City loading: lindas : Number 478
# City loading: gumdag : Number 479
# City loading: okhotsk : Number 480
# City loading: iralaya : Number 481
# City loading: smithers : Number 482
# City loading: biak : Number 483
# City loading: santa maria do para : Number 484
# City loading: bogatoye : Number 485
# City loading: lieksa : Number 486
# Error: city not found
# City loading: young : Number 487
# Error: city not found
# City loading: nhulunbuy : Number 488
# City loading: cherskiy : Number 489
# City loading: colorado : Number 490
# City loading: srednekolymsk : Number 491
# City loading: champerico : Number 492
# City loading: san vicente : Number 493
# City loading: san pedro : Number 494
# City loading: senador guiomard : Number 495
# City loading: nioro : Number 496
# City loading: morbach : Number 497
# City loading: dvinskoy : Number 498
# City loading: salalah : Number 499
# City loading: consett : Number 500
# City loading: walvis bay : Number 501
# City loading: castro : Number 502
# City loading: kaitangata : Number 503
# City loading: baruun-urt : Number 504
# City loading: sechura : Number 505
# Error: city not found
# City loading: izhma : Number 506
# City loading: huaihua : Number 507
# City loading: luangwa : Number 508
# City loading: ambon : Number 509
# City loading: iroquois falls : Number 510
# City loading: nuevo progreso : Number 511
# City loading: alausi : Number 512
# City loading: tessalit : Number 513
# City loading: iquique : Number 514
# City loading: epe : Number 515
# City loading: komsomolskiy : Number 516
# City loading: ponta delgada : Number 517
# City loading: trogir : Number 518
# City loading: ketchikan : Number 519
# Error: city not found
# City loading: havelock : Number 520
# City loading: nijar : Number 521
# City loading: upata : Number 522
# City loading: jaciara : Number 523
# City loading: ulladulla : Number 524
# Error: city not found
# City loading: yinchuan : Number 525
# City loading: nenjiang : Number 526
# Error: city not found
# City loading: les cayes : Number 527
# City loading: izumo : Number 528
# City loading: port keats : Number 529
# City loading: kasama : Number 530
# City loading: swan hill : Number 531
# City loading: gimli : Number 532
# City loading: zhoucheng : Number 533
# City loading: itaituba : Number 534
# City loading: yumen : Number 535
# Error: city not found
# City loading: sambava : Number 536
# City loading: cabinda : Number 537
# City loading: weston : Number 538
# City loading: la asuncion : Number 539
# City loading: half moon bay : Number 540
# City loading: bardiyah : Number 541
# City loading: den helder : Number 542
# City loading: tecoanapa : Number 543
# City loading: klaksvik : Number 544
# City loading: shaowu : Number 545
# City loading: gazanjyk : Number 546
# City loading: fomboni : Number 547
# Error: city not found
# City loading: taoudenni : Number 548
# City loading: gouyave : Number 549
# City loading: belmonte : Number 550
# City loading: xinye : Number 551
# City loading: general roca : Number 552
# City loading: cauquenes : Number 553
# City loading: rock falls : Number 554
# City loading: pochutla : Number 555
# City loading: zhuhai : Number 556
# City loading: uchiza : Number 557
# City loading: gizo : Number 558
# City loading: vizinga : Number 559
# City loading: zakamensk : Number 560
# City loading: broome : Number 561
# City loading: manakara : Number 562
# City loading: dunedin : Number 563
# City loading: danane : Number 564
# City loading: nome : Number 565
# City loading: rorvik : Number 566
# City loading: nokaneng : Number 567
# City loading: vangaindrano : Number 568
# City loading: toppenish : Number 569
# City loading: amargosa : Number 570
# City loading: aparecida do taboado : Number 571
# City loading: okha : Number 572
# City loading: buraydah : Number 573
# City loading: grants : Number 574
# City loading: arona : Number 575
# City loading: porto novo : Number 576
# City loading: yeppoon : Number 577

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_dict = pd.DataFrame({"City Name": city_name,
                          "Temp": temp,
                          "Feels Like": feels_like,
                          "Max Temp": temp_max,
                         "Min Temp": temp_min,
                         "Pressure": pressure,
                         "Humidity": humidity,
                         "Visibility": visibility,
                         "Latitude": lat,
                         "Longitude": lng,
                         "Cloudiness": cloudiness,
                        "Date": date,
                        "Country": country,
                         "Wind Speed": wind_speed})

#city_data = pd.DataFrame(city_dict)
city_dict.to_csv("city_data.csv")
city_dict.head()
# Out:
#        City Name    Temp  Feels Like  Max Temp  Min Temp  Pressure  Humidity  \
# 0        Mataura  283.15      282.97    283.15    283.15      1008        91
# 1       Thompson  274.15      269.41    274.15    274.15      1017        64
# 2  Batagay-Alyta  259.32      253.85    259.32    259.32       991        91
# 3       Carballo  288.30      287.20    289.15    287.04      1020        51
# 4     Bredasdorp  285.15      284.86    285.15    285.15      1017        94
#
#    Visibility  Latitude  Longitude  Cloudiness        Date Country  Wind Speed
# 0       10000  -46.1927   168.8643         100  1618683941      NZ        1.34
# 1       10000   55.7435   -97.8558          90  1618684071      CA        5.14
# 2        9250   67.8006   130.4114         100  1618684052      RU        2.43
# 3       10000   43.2130    -8.6910           0  1618684162      ES        2.57
# 4       10000  -34.5322    20.0403          27  1618683793      ZA        1.03

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
humidity_hundreds = city_dict.loc[city_dict["Humidity"] == 100]
clean_data = city_dict[city_dict["Humidity"] < 100]

# %%
#  Get the indices of cities that have humidity over 100%.
humidity_hundreds.reset_index()
# Out:
#    index     City Name    Temp  Feels Like  Max Temp  Min Temp  Pressure  \
# 0     29         Cooma  275.15      275.15    275.15    275.15      1022
# 1    106  Christchurch  278.37      278.37    281.48    275.15      1010
# 2    107        Dikson  246.73      240.77    246.73    246.73      1019
# 3    117     Glace Bay  274.57      268.40    275.37    274.15      1010
# 4    312      Linqiong  288.15      288.32    288.15    288.15      1018
# 5    394    Nelson Bay  284.84      284.68    285.37    284.15      1021
# 6    524     Ulladulla  283.42      283.11    284.82    281.48      1021
#
#    Humidity  Visibility  Latitude  Longitude  Cloudiness        Date Country  \
# 0       100       10000  -36.2333   149.1333          90  1618684169      AU
# 1       100       10000  -43.5333   172.6333           9  1618683907      NZ
# 2       100       10000   73.5069    80.5464          55  1618684192      RU
# 3       100        3219   46.1969   -59.9570          90  1618684194      CA
# 4       100        3000   30.4159   103.4609          75  1618684261      CN
# 5       100         900  -32.7167   152.1500          90  1618684291      AU
# 6       100       10000  -35.3500   150.4667          90  1618684334      AU
#
#    Wind Speed
# 0        0.83
# 1        1.03
# 2        1.67
# 3        8.75
# 4        2.00
# 5        5.14
# 6        3.09

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
clean_city_data = clean_data.reset_index(inplace=False)

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
#cryptic_date = clean_city_data["Date"][0]
clean_city_data["Date"] = pd.to_datetime(clean_city_data["Date"],unit="s")
datestamp = clean_city_data["Date"].mean()

mpl.scatter(clean_city_data["Latitude"], clean_city_data["Max Temp"], color = "pink", marker = "D", alpha=1, edgecolor="black")
mpl.xlabel("Latitude")
mpl.ylabel("Maximum Temperature")
mpl.title(f"Latitude vs. Max Temperature + ({datestamp})")
mpl.grid()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
mpl.scatter(clean_city_data["Latitude"], clean_city_data["Humidity"], color = "limegreen", marker = "x", alpha=1, edgecolor="black")
mpl.xlabel("Latitude")
mpl.ylabel("Humidity")
mpl.title(f"Latitude vs. Humidity {datestamp}")
mpl.grid()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
mpl.scatter(clean_city_data["Latitude"], clean_city_data["Cloudiness"], color = "blue", marker = ">", alpha=1, edgecolor="green")
mpl.xlabel("Latitude")
mpl.ylabel("Cloudiness")
mpl.grid()
mpl.title(f"Latitude vs. Cloudiness {datestamp}")
# Out:
# Text(0.5, 1.0, 'Latitude vs. Cloudiness 2021-04-17 18:30:10.325744128')

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
mpl.scatter(clean_city_data["Latitude"], clean_city_data["Wind Speed"], color = "orange", marker = "P", alpha=1, edgecolor="blue")

mpl.xlabel("Latitude")
mpl.ylabel("Wind Speed")
mpl.grid()
mpl.title(f"Latitude vs. Wind Speed {datestamp}")
# Out:
# Text(0.5, 1.0, 'Latitude vs. Wind Speed 2021-04-17 18:30:10.325744128')

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.46937863826630627

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.6082708688906918

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.000543987878808455

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.014985174297345524

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.0020898727664228514

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.0035263772085582894

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.04019723576144484

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.017128274759839232
